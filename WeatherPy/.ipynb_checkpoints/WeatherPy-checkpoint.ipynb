# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from matplotlib import cm

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
# View format of information for accessing data
url1 = f"http://api.openweathermap.org/data/2.5/weather?q={cities[0]}&units=imperial&appid={weather_api_key}"

response = requests.get(url1).json()   

print(json.dumps(response, indent=4, sort_keys=False))
# Out:
# {
#     "coord": {
#         "lon": 121.9,
#         "lat": -33.8667
#     },
#     "weather": [
#         {
#             "id": 804,
#             "main": "Clouds",
#             "description": "overcast clouds",
#             "icon": "04d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 77,
#         "feels_like": 68.13,
#         "temp_min": 77,
#         "temp_max": 77,
#         "pressure": 1018,
#         "humidity": 36
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 14.97,
#         "deg": 360
#     },
#     "clouds": {
#         "all": 98
#     },
#     "dt": 1615946254,
#     "sys": {
#         "type": 1,
#         "id": 9525,
#         "country": "AU",
#         "sunrise": 1615931586,
#         "sunset": 1615975717
#     },
#     "timezone": 28800,
#     "id": 2071860,
#     "name": "Esperance",
#     "cod": 200
# }

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create variables to store the necessary data
lat = []
lon = []
maxTemp = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []
cit = []

print("Beginning Data Retrieval")
print("-----------------------------")

# Counter to print city numbers
cityNum = 1

# For loop to interate through the cities and request the data from the API
for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}"
    
    # Make sure there is data to collect on the city
    try:
        # Get the reponse from the API
        response = requests.get(url).json()
        # Load variables with the necessary data
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        maxTemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        cit.append(city)
        # Print the record of the city being proccessed
        print(f"Processing Record {cityNum} | {city}")
        # Update the counter for the next city
        cityNum += 1
    # Output line if the city is not found
    except:
        print("City not found. Skipping...")
        
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | esperance
# Processing Record 2 | yekimovichi
# Processing Record 3 | banyo
# Processing Record 4 | areosa
# Processing Record 5 | norman wells
# Processing Record 6 | kruisfontein
# City not found. Skipping...
# Processing Record 7 | ekuvukeni
# Processing Record 8 | hobart
# Processing Record 9 | mataura
# Processing Record 10 | victoria
# Processing Record 11 | kapaa
# Processing Record 12 | alakurtti
# Processing Record 13 | aklavik
# Processing Record 14 | kurdzhinovo
# Processing Record 15 | hamilton
# Processing Record 16 | petropavlovsk-kamchatskiy
# Processing Record 17 | atuona
# City not found. Skipping...
# Processing Record 18 | puerto ayora
# Processing Record 19 | nikolskoye
# Processing Record 20 | touros
# Processing Record 21 | sorong
# Processing Record 22 | oranjestad
# Processing Record 23 | forestville
# Processing Record 24 | avarua
# Processing Record 25 | asau
# Processing Record 26 | nanortalik
# Processing Record 27 | matamoros
# Processing Record 28 | bluff
# Processing Record 29 | yellowknife
# City not found. Skipping...
# Processing Record 30 | jamestown
# City not found. Skipping...
# Processing Record 31 | tasiilaq
# Processing Record 32 | provideniya
# Processing Record 33 | cape town
# Processing Record 34 | punta arenas
# Processing Record 35 | port lincoln
# Processing Record 36 | port elizabeth
# Processing Record 37 | new norfolk
# Processing Record 38 | lebu
# Processing Record 39 | bredasdorp
# Processing Record 40 | pimentel
# City not found. Skipping...
# Processing Record 41 | georgetown
# Processing Record 42 | itanhem
# Processing Record 43 | ushumun
# Processing Record 44 | severo-kurilsk
# Processing Record 45 | puerto madryn
# Processing Record 46 | tarki
# Processing Record 47 | barrow
# Processing Record 48 | airai
# Processing Record 49 | bubaque
# Processing Record 50 | port alfred
# Processing Record 51 | ribeira grande
# Processing Record 52 | basco
# Processing Record 53 | kodiak
# Processing Record 54 | bacalar
# Processing Record 55 | dikson
# Processing Record 56 | padang
# Processing Record 57 | taoudenni
# Processing Record 58 | mecca
# City not found. Skipping...
# Processing Record 59 | rikitea
# Processing Record 60 | hermanus
# Processing Record 61 | khatanga
# Processing Record 62 | raahe
# City not found. Skipping...
# Processing Record 63 | safford
# Processing Record 64 | chuy
# Processing Record 65 | kollam
# Processing Record 66 | port hedland
# Processing Record 67 | athabasca
# Processing Record 68 | hithadhoo
# Processing Record 69 | ushuaia
# Processing Record 70 | digras
# Processing Record 71 | saraland
# Processing Record 72 | san quintin
# Processing Record 73 | qaanaaq
# Processing Record 74 | saint george
# Processing Record 75 | katsuura
# Processing Record 76 | akyab
# Processing Record 77 | vung tau
# Processing Record 78 | pierre
# Processing Record 79 | busselton
# City not found. Skipping...
# Processing Record 80 | klimovo
# Processing Record 81 | mirnyy
# Processing Record 82 | key largo
# City not found. Skipping...
# Processing Record 83 | horki
# Processing Record 84 | port blair
# Processing Record 85 | tiksi
# Processing Record 86 | saint-philippe
# Processing Record 87 | saint-pierre
# Processing Record 88 | santa maria del oro
# Processing Record 89 | castro
# City not found. Skipping...
# Processing Record 90 | east london
# Processing Record 91 | luderitz
# Processing Record 92 | goderich
# Processing Record 93 | oistins
# Processing Record 94 | ballina
# Processing Record 95 | mar del plata
# City not found. Skipping...
# Processing Record 96 | vaini
# City not found. Skipping...
# Processing Record 97 | pacific grove
# Processing Record 98 | isangel
# Processing Record 99 | road town
# Processing Record 100 | albany
# Processing Record 101 | gherghesti
# Processing Record 102 | biak
# Processing Record 103 | kieta
# City not found. Skipping...
# Processing Record 104 | kaeo
# Processing Record 105 | ambon
# City not found. Skipping...
# Processing Record 106 | kaitangata
# Processing Record 107 | zabaykalsk
# Processing Record 108 | hilo
# Processing Record 109 | narsaq
# Processing Record 110 | smithers
# Processing Record 111 | lagoa
# Processing Record 112 | hofn
# Processing Record 113 | jalu
# Processing Record 114 | marshall
# City not found. Skipping...
# Processing Record 115 | ancud
# Processing Record 116 | mount gambier
# Processing Record 117 | preobrazheniye
# Processing Record 118 | pampilhosa
# Processing Record 119 | san patricio
# Processing Record 120 | vardo
# Processing Record 121 | cidreira
# Processing Record 122 | cherskiy
# Processing Record 123 | vikulovo
# Processing Record 124 | san vicente
# Processing Record 125 | iqaluit
# Processing Record 126 | longyearbyen
# Processing Record 127 | araouane
# Processing Record 128 | cacu
# Processing Record 129 | makakilo city
# City not found. Skipping...
# Processing Record 130 | marogong
# Processing Record 131 | saskylakh
# Processing Record 132 | andros town
# Processing Record 133 | sao filipe
# Processing Record 134 | geraldton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 135 | iquique
# Processing Record 136 | tuktoyaktuk
# Processing Record 137 | timmins
# Processing Record 138 | catamarca
# Processing Record 139 | mahebourg
# Processing Record 140 | fortuna
# Processing Record 141 | marica
# Processing Record 142 | butaritari
# Processing Record 143 | san jose
# Processing Record 144 | kloulklubed
# Processing Record 145 | empalme
# Processing Record 146 | kupino
# Processing Record 147 | pevek
# Processing Record 148 | port keats
# Processing Record 149 | berlevag
# Processing Record 150 | carnarvon
# Processing Record 151 | hami
# Processing Record 152 | portland
# Processing Record 153 | sawtell
# Processing Record 154 | upernavik
# Processing Record 155 | tiarei
# Processing Record 156 | pisco
# Processing Record 157 | constantine
# City not found. Skipping...
# Processing Record 158 | cururupu
# Processing Record 159 | karratha
# Processing Record 160 | caravelas
# Processing Record 161 | bontang
# Processing Record 162 | alofi
# Processing Record 163 | codrington
# Processing Record 164 | sao joao da barra
# Processing Record 165 | baiyin
# Processing Record 166 | garowe
# Processing Record 167 | camacupa
# Processing Record 168 | progreso
# Processing Record 169 | souillac
# Processing Record 170 | okhotsk
# Processing Record 171 | lima
# Processing Record 172 | solano
# City not found. Skipping...
# Processing Record 173 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 174 | moose factory
# Processing Record 175 | waseca
# Processing Record 176 | chokurdakh
# Processing Record 177 | yerbogachen
# City not found. Skipping...
# Processing Record 178 | ahipara
# Processing Record 179 | san cristobal
# Processing Record 180 | aguada de pasajeros
# Processing Record 181 | gweta
# Processing Record 182 | yurginskoye
# Processing Record 183 | mandalgovi
# Processing Record 184 | urumqi
# Processing Record 185 | cabedelo
# Processing Record 186 | vostok
# Processing Record 187 | lompoc
# Processing Record 188 | talnakh
# Processing Record 189 | abha
# Processing Record 190 | burns lake
# Processing Record 191 | antalaha
# Processing Record 192 | labuhan
# Processing Record 193 | buchanan
# Processing Record 194 | gobabis
# Processing Record 195 | tocopilla
# Processing Record 196 | valleyview
# Processing Record 197 | kutum
# Processing Record 198 | namanga
# City not found. Skipping...
# Processing Record 199 | aberdeen
# Processing Record 200 | goundam
# Processing Record 201 | ponta do sol
# Processing Record 202 | kathmandu
# Processing Record 203 | faanui
# Processing Record 204 | torbay
# Processing Record 205 | darhan
# Processing Record 206 | kerema
# Processing Record 207 | la ronge
# City not found. Skipping...
# Processing Record 208 | manzanillo
# Processing Record 209 | iyo
# Processing Record 210 | honiara
# Processing Record 211 | barda
# Processing Record 212 | salvador
# Processing Record 213 | kahului
# Processing Record 214 | newport
# Processing Record 215 | miram shah
# Processing Record 216 | bolton
# Processing Record 217 | usinsk
# Processing Record 218 | carutapera
# City not found. Skipping...
# Processing Record 219 | launceston
# Processing Record 220 | houma
# Processing Record 221 | mala
# Processing Record 222 | panguna
# Processing Record 223 | belaya gora
# Processing Record 224 | gabu
# Processing Record 225 | najran
# Processing Record 226 | coquimbo
# Processing Record 227 | strezhevoy
# Processing Record 228 | canico
# Processing Record 229 | dingle
# Processing Record 230 | micheweni
# Processing Record 231 | tadine
# Processing Record 232 | kyaiklat
# Processing Record 233 | new richmond
# Processing Record 234 | rawson
# Processing Record 235 | aksarka
# Processing Record 236 | havre-saint-pierre
# Processing Record 237 | setermoen
# Processing Record 238 | tucupita
# Processing Record 239 | pestravka
# Processing Record 240 | saldanha
# Processing Record 241 | mumford
# Processing Record 242 | kavieng
# Processing Record 243 | ilulissat
# Processing Record 244 | fort nelson
# Processing Record 245 | ust-tarka
# Processing Record 246 | sisimiut
# Processing Record 247 | marsh harbour
# Processing Record 248 | shimoda
# Processing Record 249 | salalah
# Processing Record 250 | southbridge
# Processing Record 251 | kirkwall
# Processing Record 252 | soyo
# Processing Record 253 | montrose
# Processing Record 254 | sorland
# Processing Record 255 | skvyra
# Processing Record 256 | moron
# Processing Record 257 | nabire
# Processing Record 258 | ulaanbaatar
# Processing Record 259 | port moresby
# Processing Record 260 | arraial do cabo
# Processing Record 261 | mount isa
# Processing Record 262 | veracruz
# Processing Record 263 | saint austell
# Processing Record 264 | yazman
# Processing Record 265 | mehamn
# Processing Record 266 | fandriana
# Processing Record 267 | hurghada
# Processing Record 268 | oranjemund
# City not found. Skipping...
# Processing Record 269 | ulcinj
# Processing Record 270 | mao
# Processing Record 271 | saint-ambroise
# Processing Record 272 | portree
# Processing Record 273 | dawei
# Processing Record 274 | papagaios
# Processing Record 275 | novopavlovka
# Processing Record 276 | vila velha
# Processing Record 277 | baiquan
# Processing Record 278 | coihaique
# Processing Record 279 | nome
# Processing Record 280 | waitara
# Processing Record 281 | aldama
# Processing Record 282 | broome
# City not found. Skipping...
# Processing Record 283 | traunstein
# Processing Record 284 | itarema
# Processing Record 285 | aksay
# Processing Record 286 | henderson
# Processing Record 287 | aripuana
# Processing Record 288 | hervey bay
# Processing Record 289 | waipawa
# Processing Record 290 | naifaru
# Processing Record 291 | rivoli
# Processing Record 292 | voh
# Processing Record 293 | konya
# Processing Record 294 | clyde river
# Processing Record 295 | riyadh
# Processing Record 296 | negombo
# Processing Record 297 | dimbokro
# Processing Record 298 | uyovu
# Processing Record 299 | mishan
# Processing Record 300 | ust-tsilma
# Processing Record 301 | salinopolis
# Processing Record 302 | canon city
# Processing Record 303 | rudnaya pristan
# Processing Record 304 | saint-joseph
# Processing Record 305 | colon
# Processing Record 306 | olafsvik
# City not found. Skipping...
# Processing Record 307 | severnyy-kospashskiy
# Processing Record 308 | camabatela
# Processing Record 309 | alyangula
# Processing Record 310 | lasa
# Processing Record 311 | hasaki
# Processing Record 312 | kenai
# Processing Record 313 | san ramon
# Processing Record 314 | mahon
# Processing Record 315 | rocha
# Processing Record 316 | bathsheba
# Processing Record 317 | las guacamayas
# Processing Record 318 | buala
# Processing Record 319 | dombarovskiy
# Processing Record 320 | hambantota
# Processing Record 321 | kamaishi
# Processing Record 322 | mitoc
# Processing Record 323 | dabrowa tarnowska
# Processing Record 324 | namibe
# Processing Record 325 | yumen
# City not found. Skipping...
# Processing Record 326 | mahina
# Processing Record 327 | chase
# Processing Record 328 | tucurui
# Processing Record 329 | zyryanka
# Processing Record 330 | juegang
# City not found. Skipping...
# Processing Record 331 | paramonga
# Processing Record 332 | kamyshlov
# City not found. Skipping...
# Processing Record 333 | kabalo
# Processing Record 334 | marand
# Processing Record 335 | mazagao
# Processing Record 336 | lata
# Processing Record 337 | nuuk
# Processing Record 338 | josanicka banja
# Processing Record 339 | ko samui
# Processing Record 340 | kabare
# City not found. Skipping...
# Processing Record 341 | ponta delgada
# Processing Record 342 | bambous virieux
# Processing Record 343 | leningradskiy
# Processing Record 344 | great yarmouth
# City not found. Skipping...
# Processing Record 345 | omsukchan
# Processing Record 346 | valdivia
# Processing Record 347 | aleksandrovka
# Processing Record 348 | yar-sale
# Processing Record 349 | teya
# Processing Record 350 | pitimbu
# Processing Record 351 | tarko-sale
# City not found. Skipping...
# Processing Record 352 | arkadak
# Processing Record 353 | faya
# Processing Record 354 | esso
# Processing Record 355 | boa vista
# Processing Record 356 | comodoro rivadavia
# Processing Record 357 | leh
# Processing Record 358 | bintulu
# Processing Record 359 | rognan
# Processing Record 360 | chumikan
# Processing Record 361 | verkhnyaya toyma
# Processing Record 362 | atar
# Processing Record 363 | ornskoldsvik
# Processing Record 364 | mahanoro
# Processing Record 365 | san juan
# Processing Record 366 | puerto quijarro
# Processing Record 367 | kiunga
# City not found. Skipping...
# Processing Record 368 | port macquarie
# City not found. Skipping...
# Processing Record 369 | biloela
# Processing Record 370 | takahashi
# Processing Record 371 | la asuncion
# Processing Record 372 | sao felix do xingu
# Processing Record 373 | bowen
# Processing Record 374 | laguna
# Processing Record 375 | tarakan
# Processing Record 376 | cartama
# Processing Record 377 | tuatapere
# Processing Record 378 | flinders
# Processing Record 379 | vila
# Processing Record 380 | bafra
# Processing Record 381 | quzhou
# Processing Record 382 | troitskoye
# Processing Record 383 | tamandare
# Processing Record 384 | dubbo
# Processing Record 385 | praia da vitoria
# Processing Record 386 | kayerkan
# Processing Record 387 | huambo
# City not found. Skipping...
# Processing Record 388 | thompson
# Processing Record 389 | cusuna
# Processing Record 390 | kot diji
# Processing Record 391 | port alberni
# Processing Record 392 | flin flon
# Processing Record 393 | cooma
# City not found. Skipping...
# Processing Record 394 | aykhal
# Processing Record 395 | beringovskiy
# City not found. Skipping...
# Processing Record 396 | kazachinskoye
# Processing Record 397 | doka
# Processing Record 398 | navrongo
# Processing Record 399 | bilma
# Processing Record 400 | menongue
# Processing Record 401 | muyezerskiy
# Processing Record 402 | batagay-alyta
# Processing Record 403 | chudovo
# City not found. Skipping...
# Processing Record 404 | sur
# Processing Record 405 | fairbanks
# Processing Record 406 | baruun-urt
# Processing Record 407 | guerrero negro
# Processing Record 408 | kumluca
# Processing Record 409 | tura
# Processing Record 410 | ames
# Processing Record 411 | kholtoson
# Processing Record 412 | ferrol
# Processing Record 413 | vieux-habitants
# Processing Record 414 | mokhsogollokh
# Processing Record 415 | panjakent
# Processing Record 416 | inuvik
# Processing Record 417 | gorontalo
# Processing Record 418 | maceio
# Processing Record 419 | adet
# Processing Record 420 | tsimlyansk
# City not found. Skipping...
# Processing Record 421 | lavrentiya
# Processing Record 422 | muros
# Processing Record 423 | tabou
# Processing Record 424 | coahuayana
# Processing Record 425 | klaksvik
# Processing Record 426 | stillwater
# Processing Record 427 | cockburn town
# Processing Record 428 | gizo
# Processing Record 429 | salina
# Processing Record 430 | mandera
# Processing Record 431 | sola
# Processing Record 432 | te anau
# Processing Record 433 | dakar
# Processing Record 434 | adrar
# Processing Record 435 | lixourion
# Processing Record 436 | bezhanitsy
# Processing Record 437 | yulara
# Processing Record 438 | tokur
# City not found. Skipping...
# Processing Record 439 | manicore
# Processing Record 440 | ratnagiri
# Processing Record 441 | alice springs
# Processing Record 442 | bin qirdan
# Processing Record 443 | tibagi
# Processing Record 444 | traverse city
# Processing Record 445 | bowmore
# Processing Record 446 | pirovskoye
# Processing Record 447 | hajipur
# Processing Record 448 | waitati
# Processing Record 449 | sitka
# Processing Record 450 | piopio
# Processing Record 451 | westport
# Processing Record 452 | vesoul
# Processing Record 453 | vao
# Processing Record 454 | bairiki
# Processing Record 455 | aksu
# Processing Record 456 | lodwar
# Processing Record 457 | tessalit
# Processing Record 458 | mujiayingzi
# Processing Record 459 | sylacauga
# Processing Record 460 | oksfjord
# Processing Record 461 | cap-aux-meules
# Processing Record 462 | quelimane
# Processing Record 463 | clinton
# Processing Record 464 | sambava
# Processing Record 465 | hays
# Processing Record 466 | high rock
# City not found. Skipping...
# Processing Record 467 | mopti
# Processing Record 468 | suslovo
# Processing Record 469 | surt
# Processing Record 470 | umm lajj
# City not found. Skipping...
# Processing Record 471 | rio gallegos
# Processing Record 472 | zyryanovsk
# Processing Record 473 | malakal
# Processing Record 474 | bengkulu
# Processing Record 475 | potsdam
# Processing Record 476 | cap malheureux
# Processing Record 477 | spokane
# Processing Record 478 | zhezkazgan
# Processing Record 479 | savinka
# Processing Record 480 | baie-comeau
# Processing Record 481 | mayo
# Processing Record 482 | majene
# Processing Record 483 | baykit
# Processing Record 484 | bam
# Processing Record 485 | lorengau
# Processing Record 486 | mahibadhoo
# Processing Record 487 | srednekolymsk
# Processing Record 488 | camalu
# Processing Record 489 | trat
# Processing Record 490 | miedzyrzecz
# Processing Record 491 | verkhnyaya inta
# Processing Record 492 | cotonou
# Processing Record 493 | amahai
# Processing Record 494 | constitucion
# Processing Record 495 | puerto escondido
# Processing Record 496 | khandyga
# Processing Record 497 | tupiza
# Processing Record 498 | togur
# Processing Record 499 | okha
# Processing Record 500 | bismarck
# Processing Record 501 | san policarpo
# Processing Record 502 | waingapu
# Processing Record 503 | isla vista
# Processing Record 504 | haines junction
# Processing Record 505 | vanavara
# Processing Record 506 | burnie
# Processing Record 507 | bethel
# Processing Record 508 | kampong chhnang
# Processing Record 509 | mamallapuram
# City not found. Skipping...
# Processing Record 510 | richards bay
# Processing Record 511 | college
# Processing Record 512 | salaga
# Processing Record 513 | grand forks
# Processing Record 514 | iralaya
# Processing Record 515 | lashio
# Processing Record 516 | tezu
# Processing Record 517 | sanjwal
# Processing Record 518 | lannion
# Processing Record 519 | cuiluan
# Processing Record 520 | gisborne
# Processing Record 521 | cayenne
# Processing Record 522 | bandar
# Processing Record 523 | killybegs
# Processing Record 524 | coro
# Processing Record 525 | paamiut
# Processing Record 526 | stade
# City not found. Skipping...
# Processing Record 527 | vila franca do campo
# Processing Record 528 | acarau
# Processing Record 529 | kropotkin
# Processing Record 530 | aljezur
# Processing Record 531 | half moon bay
# Processing Record 532 | xuanhua
# Processing Record 533 | luwuk
# Processing Record 534 | pokrovsk
# Processing Record 535 | san pedro
# Processing Record 536 | imbituba
# Processing Record 537 | volgodonsk
# Processing Record 538 | asfi
# Processing Record 539 | jijiga
# Processing Record 540 | sangar
# City not found. Skipping...
# Processing Record 541 | khasan
# Processing Record 542 | aktau
# Processing Record 543 | cascais
# Processing Record 544 | boshnyakovo
# Processing Record 545 | guadalupe y calvo
# Processing Record 546 | balsas
# Processing Record 547 | cabo san lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 548 | furano
# Processing Record 549 | north bend
# Processing Record 550 | samfya
# Processing Record 551 | katangli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | rangapara
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | kota bahru
# Processing Record 29 of Set 1 | rocha
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | umm lajj
# Processing Record 32 of Set 1 | zvenyhorodka
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | ayan
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | mount isa
# Processing Record 42 of Set 1 | beringovskiy
# Processing Record 43 of Set 1 | shu
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | isla vista
# Processing Record 0 of Set 2 | arroyo
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 2 | caimito
# Processing Record 5 of Set 2 | amalapuram
# Processing Record 6 of Set 2 | moree
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | kiunga
# Processing Record 10 of Set 2 | antalaha
# Processing Record 11 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 2 | eureka
# Processing Record 15 of Set 2 | ust-maya
# Processing Record 16 of Set 2 | barraute
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 2 | farafangana
# Processing Record 21 of Set 2 | mporokoso
# Processing Record 22 of Set 2 | leningradskiy
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | yumen
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 2 | shenzhen
# Processing Record 29 of Set 2 | dingle
# Processing Record 30 of Set 2 | labuhan
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | zhangjiakou
# Processing Record 34 of Set 2 | olga
# Processing Record 35 of Set 2 | luganville
# Processing Record 36 of Set 2 | jinchang
# Processing Record 37 of Set 2 | lagoa
# Processing Record 38 of Set 2 | strezhevoy
# Processing Record 39 of Set 2 | bauchi
# Processing Record 40 of Set 2 | shimoda
# Processing Record 41 of Set 2 | kieta
# Processing Record 42 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 2 | poum
# Processing Record 44 of Set 2 | san cristobal
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | conde
# Processing Record 49 of Set 2 | sal rei
# Processing Record 0 of Set 3 | dikson
# Processing Record 1 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | samarinda
# Processing Record 4 of Set 3 | mwinilunga
# Processing Record 5 of Set 3 | chernyshkovskiy
# Processing Record 6 of Set 3 | takapau
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | kysyl-syr
# Processing Record 9 of Set 3 | butembo
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | oktyabrskiy
# Processing Record 14 of Set 3 | malanje
# Processing Record 15 of Set 3 | topolog
# Processing Record 16 of Set 3 | bogorodskoye
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | saint-paul
# Processing Record 21 of Set 3 | vanavara
# Processing Record 22 of Set 3 | mitsamiouli
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | yuzhno-kurilsk
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | yellowknife
# Processing Record 31 of Set 3 | flin flon
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | buraydah
# Processing Record 34 of Set 3 | dauphin
# Processing Record 35 of Set 3 | estelle
# Processing Record 36 of Set 3 | shonguy
# Processing Record 37 of Set 3 | berlevag
# Processing Record 38 of Set 3 | boyuibe
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | ikalamavony
# Processing Record 43 of Set 3 | sur
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | coihueco
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | laguna
# Processing Record 0 of Set 4 | port keats
# Processing Record 1 of Set 4 | cannington
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | sorland
# Processing Record 4 of Set 4 | trelew
# Processing Record 5 of Set 4 | kumbhraj
# Processing Record 6 of Set 4 | san blas
# Processing Record 7 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 4 | buala
# Processing Record 9 of Set 4 | ocos
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 4 | kalaleh
# Processing Record 14 of Set 4 | tornio
# Processing Record 15 of Set 4 | bar harbor
# Processing Record 16 of Set 4 | jiangyou
# Processing Record 17 of Set 4 | xingyi
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | misratah
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | elizabeth city
# Processing Record 24 of Set 4 | baiyin
# Processing Record 25 of Set 4 | matara
# Processing Record 26 of Set 4 | ambilobe
# Processing Record 27 of Set 4 | yelizovo
# Processing Record 28 of Set 4 | messina
# Processing Record 29 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 4 | puerto ayora
# Processing Record 31 of Set 4 | malindi
# Processing Record 32 of Set 4 | plettenberg bay
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | hay river
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | chimbote
# Processing Record 37 of Set 4 | kanor
# Processing Record 38 of Set 4 | san pedro de uraba
# Processing Record 39 of Set 4 | taphan hin
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | matagami
# Processing Record 42 of Set 4 | terme
# Processing Record 43 of Set 4 | coria
# Processing Record 44 of Set 4 | pallasovka
# Processing Record 45 of Set 4 | asyut
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | osypenko
# Processing Record 48 of Set 4 | sioux lookout
# Processing Record 49 of Set 4 | gotsu
# Processing Record 0 of Set 5 | abadan
# Processing Record 1 of Set 5 | lewistown
# Processing Record 2 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | ostersund
# Processing Record 5 of Set 5 | calafell
# Processing Record 6 of Set 5 | panguna
# Processing Record 7 of Set 5 | nantucket
# Processing Record 8 of Set 5 | la ronge
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | monte azul
# Processing Record 11 of Set 5 | binga
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | ushirombo
# Processing Record 14 of Set 5 | guerrero negro
# Processing Record 15 of Set 5 | sobradinho
# Processing Record 16 of Set 5 | saint-leu
# Processing Record 17 of Set 5 | rabo de peixe
# Processing Record 18 of Set 5 | cabedelo
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | kirakira
# Processing Record 22 of Set 5 | we
# City not found. Skipping...
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | mosetse
# Processing Record 25 of Set 5 | storforshei
# Processing Record 26 of Set 5 | nuuk
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 5 | lang suan
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | atuona
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | kasempa
# Processing Record 34 of Set 5 | maldonado
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | tacarigua
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | maryborough
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | nalut
# Processing Record 44 of Set 5 | ginda
# Processing Record 45 of Set 5 | iquique
# Processing Record 46 of Set 5 | boa vista
# Processing Record 47 of Set 5 | hofn
# Processing Record 48 of Set 5 | fowa
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 0 of Set 6 | rio gallegos
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | hargeysa
# Processing Record 3 of Set 6 | ormara
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | nosy varika
# Processing Record 6 of Set 6 | lanzhou
# Processing Record 7 of Set 6 | umm kaddadah
# Processing Record 8 of Set 6 | muyezerskiy
# Processing Record 9 of Set 6 | boyolangu
# Processing Record 10 of Set 6 | tuatapere
# Processing Record 11 of Set 6 | yamada
# Processing Record 12 of Set 6 | makokou
# Processing Record 13 of Set 6 | ust-kuyga
# Processing Record 14 of Set 6 | teahupoo
# Processing Record 15 of Set 6 | yele
# Processing Record 16 of Set 6 | moose factory
# Processing Record 17 of Set 6 | baglung
# Processing Record 18 of Set 6 | cidreira
# Processing Record 19 of Set 6 | tairua
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | salta
# Processing Record 22 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 6 | vung tau
# Processing Record 24 of Set 6 | ucluelet
# Processing Record 25 of Set 6 | aksarka
# Processing Record 26 of Set 6 | fairbanks
# Processing Record 27 of Set 6 | bonavista
# Processing Record 28 of Set 6 | kayerkan
# Processing Record 29 of Set 6 | chute-aux-outardes
# Processing Record 30 of Set 6 | leh
# Processing Record 31 of Set 6 | celestun
# Processing Record 32 of Set 6 | anderson
# Processing Record 33 of Set 6 | maldaeni
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | kaitong
# Processing Record 36 of Set 6 | kondopoga
# Processing Record 37 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 6 | singkang
# Processing Record 39 of Set 6 | kyra
# Processing Record 40 of Set 6 | torbay
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | faanui
# Processing Record 43 of Set 6 | hasaki
# Processing Record 44 of Set 6 | altay
# Processing Record 45 of Set 6 | akureyri
# Processing Record 46 of Set 6 | kurumkan
# Processing Record 47 of Set 6 | miracema do tocantins
# Processing Record 48 of Set 6 | ugoofaaru
# Processing Record 49 of Set 6 | ahipara
# Processing Record 0 of Set 7 | sorkjosen
# Processing Record 1 of Set 7 | talnakh
# Processing Record 2 of Set 7 | milkovo
# Processing Record 3 of Set 7 | vanimo
# Processing Record 4 of Set 7 | majene
# Processing Record 5 of Set 7 | alta floresta
# Processing Record 6 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 7 | bluffton
# Processing Record 8 of Set 7 | lima
# Processing Record 9 of Set 7 | adrar
# Processing Record 10 of Set 7 | katangli
# Processing Record 11 of Set 7 | fort nelson
# Processing Record 12 of Set 7 | qinggang
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | paracuru
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | pacifica
# Processing Record 17 of Set 7 | sept-iles
# Processing Record 18 of Set 7 | bereda
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | honningsvag
# Processing Record 22 of Set 7 | pilar do sul
# Processing Record 23 of Set 7 | merauke
# Processing Record 24 of Set 7 | phonhong
# Processing Record 25 of Set 7 | zhuhai
# Processing Record 26 of Set 7 | havre-saint-pierre
# Processing Record 27 of Set 7 | san quintin
# Processing Record 28 of Set 7 | neiafu
# Processing Record 29 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 7 | weligama
# Processing Record 32 of Set 7 | gat
# Processing Record 33 of Set 7 | loiza
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | gawler
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | college
# Processing Record 38 of Set 7 | tomatlan
# Processing Record 39 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 7 | vostok
# Processing Record 41 of Set 7 | talaya
# Processing Record 42 of Set 7 | somanda
# Processing Record 43 of Set 7 | longyearbyen
# Processing Record 44 of Set 7 | zhigansk
# Processing Record 45 of Set 7 | thinadhoo
# Processing Record 46 of Set 7 | aripuana
# Processing Record 47 of Set 7 | brownsville
# Processing Record 48 of Set 7 | yenagoa
# Processing Record 49 of Set 7 | okhotsk
# Processing Record 0 of Set 8 | astara
# Processing Record 1 of Set 8 | lac-megantic
# Processing Record 2 of Set 8 | mutare
# Processing Record 3 of Set 8 | asau
# Processing Record 4 of Set 8 | acarau
# Processing Record 5 of Set 8 | praia
# Processing Record 6 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 8 | balabac
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | los llanos de aridane
# Processing Record 10 of Set 8 | shelburne
# Processing Record 11 of Set 8 | coihaique
# Processing Record 12 of Set 8 | montepuez
# Processing Record 13 of Set 8 | batagay
# Processing Record 14 of Set 8 | geraldton
# Processing Record 15 of Set 8 | port-cartier
# Processing Record 16 of Set 8 | tsumeb
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | korla
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | bozeman
# Processing Record 21 of Set 8 | muli
# Processing Record 22 of Set 8 | yar-sale
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 8 | hervey bay
# Processing Record 26 of Set 8 | uchiza
# Processing Record 27 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 8 | porto walter
# Processing Record 29 of Set 8 | horsham
# Processing Record 30 of Set 8 | maraa
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | garoua
# Processing Record 33 of Set 8 | kampot
# Processing Record 34 of Set 8 | marawi
# Processing Record 35 of Set 8 | egvekinot
# Processing Record 36 of Set 8 | liverpool
# Processing Record 37 of Set 8 | sanandaj
# Processing Record 38 of Set 8 | tabou
# Processing Record 39 of Set 8 | kavieng
# Processing Record 40 of Set 8 | cap malheureux
# Processing Record 41 of Set 8 | logan
# Processing Record 42 of Set 8 | klaksvik
# Processing Record 43 of Set 8 | sisimiut
# Processing Record 44 of Set 8 | whyalla
# Processing Record 45 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 8 | hailar
# Processing Record 47 of Set 8 | ajdabiya
# Processing Record 48 of Set 8 | saint-georges
# Processing Record 49 of Set 8 | hoopstad
# Processing Record 0 of Set 9 | emerald
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | fare
# Processing Record 3 of Set 9 | carballo
# Processing Record 4 of Set 9 | tan an
# Processing Record 5 of Set 9 | allapalli
# Processing Record 6 of Set 9 | santa maria
# Processing Record 7 of Set 9 | sesheke
# Processing Record 8 of Set 9 | tecoanapa
# Processing Record 9 of Set 9 | gaspe
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | toba
# Processing Record 12 of Set 9 | neu wulmstorf
# Processing Record 13 of Set 9 | wakkanai
# Processing Record 14 of Set 9 | pierre
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | arica
# Processing Record 17 of Set 9 | nsoko
# Processing Record 18 of Set 9 | krasnoarmeysk
# Processing Record 19 of Set 9 | juneau
# Processing Record 20 of Set 9 | chateauroux
# Processing Record 21 of Set 9 | kloulklubed
# Processing Record 22 of Set 9 | jiaozuo
# Processing Record 23 of Set 9 | tuburan
# Processing Record 24 of Set 9 | teknaf
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | sanski most
# Processing Record 27 of Set 9 | kaitangata
# Processing Record 28 of Set 9 | hengyang
# Processing Record 29 of Set 9 | talcahuano
# Processing Record 30 of Set 9 | arawa
# Processing Record 31 of Set 9 | mercedes
# Processing Record 32 of Set 9 | chengde
# Processing Record 33 of Set 9 | stokmarknes
# Processing Record 34 of Set 9 | kalpi
# Processing Record 35 of Set 9 | valdosta
# Processing Record 36 of Set 9 | chiampo
# Processing Record 37 of Set 9 | marsa matruh
# Processing Record 38 of Set 9 | nome
# Processing Record 39 of Set 9 | careva cuprija
# Processing Record 40 of Set 9 | port macquarie
# Processing Record 41 of Set 9 | lokosovo
# Processing Record 42 of Set 9 | rawson
# Processing Record 43 of Set 9 | skelleftea
# Processing Record 44 of Set 9 | nakasongola
# Processing Record 45 of Set 9 | lompoc
# Processing Record 46 of Set 9 | nizwa
# Processing Record 47 of Set 9 | sabang
# Processing Record 48 of Set 9 | noumea
# Processing Record 49 of Set 9 | ruteng
# Processing Record 0 of Set 10 | deputatskiy
# Processing Record 1 of Set 10 | sola
# Processing Record 2 of Set 10 | nikolayevka
# Processing Record 3 of Set 10 | tabas
# Processing Record 4 of Set 10 | qianan
# Processing Record 5 of Set 10 | vila velha
# Processing Record 6 of Set 10 | isperih
# Processing Record 7 of Set 10 | hamina
# Processing Record 8 of Set 10 | turukhansk
# Processing Record 9 of Set 10 | dodge city
# Processing Record 10 of Set 10 | espinosa
# Processing Record 11 of Set 10 | hayden
# Processing Record 12 of Set 10 | maniitsoq
# Processing Record 13 of Set 10 | camacha
# Processing Record 14 of Set 10 | vikramasingapuram
# Processing Record 15 of Set 10 | nanortalik
# Processing Record 16 of Set 10 | asmar
# Processing Record 17 of Set 10 | shingu
# Processing Record 18 of Set 10 | mattru
# Processing Record 19 of Set 10 | belgaum
# Processing Record 20 of Set 10 | taoudenni
# Processing Record 21 of Set 10 | lata
# Processing Record 22 of Set 10 | sao felix do xingu
# Processing Record 23 of Set 10 | rayachoti
# Processing Record 24 of Set 10 | sakakah
# Processing Record 25 of Set 10 | chokurdakh
# Processing Record 26 of Set 10 | konibodom
# Processing Record 27 of Set 10 | mabaruma
# Processing Record 28 of Set 10 | eyl
# Processing Record 29 of Set 10 | astoria
# Processing Record 30 of Set 10 | samarai
# Processing Record 31 of Set 10 | derzhavinsk
# Processing Record 32 of Set 10 | high level
# Processing Record 33 of Set 10 | opuwo
# Processing Record 34 of Set 10 | salinopolis
# Processing Record 35 of Set 10 | waipawa
# Processing Record 36 of Set 10 | aksu
# Processing Record 37 of Set 10 | saint paul
# Processing Record 38 of Set 10 | anadyr
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | sakaiminato
# Processing Record 41 of Set 10 | santa cruz
# Processing Record 42 of Set 10 | russkaya polyana
# Processing Record 43 of Set 10 | beipiao
# Processing Record 44 of Set 10 | srednekolymsk
# Processing Record 45 of Set 10 | tripoli
# Processing Record 46 of Set 10 | swift current
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | corbelia
# Processing Record 49 of Set 10 | roma
# Processing Record 0 of Set 11 | north bend
# Processing Record 1 of Set 11 | kiama
# Processing Record 2 of Set 11 | muroto
# Processing Record 3 of Set 11 | smidovich
# Processing Record 4 of Set 11 | conceicao do araguaia
# Processing Record 5 of Set 11 | ponta pora
# Processing Record 6 of Set 11 | bogatoye
# Processing Record 7 of Set 11 | muravlenko
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | qiongshan
# Processing Record 10 of Set 11 | saint-augustin
# Processing Record 11 of Set 11 | yilan
# Processing Record 12 of Set 11 | port blair
# Processing Record 13 of Set 11 | shakawe
# Processing Record 14 of Set 11 | alghero
# Processing Record 15 of Set 11 | bud
# Processing Record 16 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | nouadhibou
# Processing Record 19 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 11 | florianopolis
# Processing Record 21 of Set 11 | linjiang
# Processing Record 22 of Set 11 | krasnoselkup
# Processing Record 23 of Set 11 | maloy
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | aykhal
# Processing Record 26 of Set 11 | kalmeshwar
# Processing Record 27 of Set 11 | baracoa
# Processing Record 28 of Set 11 | gairo
# Processing Record 29 of Set 11 | seymchan
# Processing Record 30 of Set 11 | klaebu
# Processing Record 31 of Set 11 | beira
# Processing Record 32 of Set 11 | lebanon
# Processing Record 33 of Set 11 | cayenne
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | massape
# Processing Record 36 of Set 11 | arlit
# Processing Record 37 of Set 11 | soe
# Processing Record 38 of Set 11 | kempsey
# Processing Record 39 of Set 11 | saint-jean-port-joli
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | sao jose da coroa grande
# Processing Record 42 of Set 11 | kutum
# Processing Record 43 of Set 11 | las cruces
# Processing Record 44 of Set 11 | manta
# Processing Record 45 of Set 11 | mayumba
# Processing Record 46 of Set 11 | union
# Processing Record 47 of Set 11 | brae
# Processing Record 48 of Set 11 | otane
# Processing Record 49 of Set 11 | rio muerto
# Processing Record 0 of Set 12 | polunochnoye
# Processing Record 1 of Set 12 | artigas
# Processing Record 2 of Set 12 | lalibela
# Processing Record 3 of Set 12 | castelo branco
# Processing Record 4 of Set 12 | moron
# Processing Record 5 of Set 12 | naze
# Processing Record 6 of Set 12 | natal
# Processing Record 7 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 12 | walvis bay
# Processing Record 9 of Set 12 | tarbagatay
# Processing Record 10 of Set 12 | kamenka
# Processing Record 11 of Set 12 | qaqortoq
# Processing Record 12 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | paita
# Processing Record 15 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 12 | kaohsiung
# Processing Record 17 of Set 12 | shache
# Processing Record 18 of Set 12 | divnoye
# Processing Record 19 of Set 12 | barra dos coqueiros
# Processing Record 20 of Set 12 | provideniya
# Processing Record 21 of Set 12 | norman wells
# Processing Record 22 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | follonica
# Processing Record 24 of Set 12 | verkhoyansk
# Processing Record 25 of Set 12 | henties bay
# Processing Record 26 of Set 12 | kudahuvadhoo
# Processing Record 27 of Set 12 | bandundu
# Processing Record 28 of Set 12 | cascais
# Processing Record 29 of Set 12 | dickinson
# Processing Record 30 of Set 12 | san benito
# Processing Record 31 of Set 12 | kenai
# Processing Record 32 of Set 12 | rio pardo de minas
# Processing Record 33 of Set 12 | erzin
# Processing Record 34 of Set 12 | san carlos del zulia
# Processing Record 35 of Set 12 | kyshtovka
# Processing Record 36 of Set 12 | zima
# Processing Record 37 of Set 12 | khandbari
# Processing Record 38 of Set 12 | salyan
# Processing Record 39 of Set 12 | saint-joseph
# Processing Record 40 of Set 12 | tocopilla
# Processing Record 41 of Set 12 | ust-nera
# Processing Record 42 of Set 12 | yangambi
# Processing Record 43 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 12 | shirakamut
# Processing Record 45 of Set 12 | berezovyy
# Processing Record 46 of Set 12 | dunedin
# Processing Record 47 of Set 12 | bonthe
# Processing Record 48 of Set 12 | sijunjung
# Processing Record 49 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 0 of Set 13 | atar
# Processing Record 1 of Set 13 | fayaoue
# Processing Record 2 of Set 13 | san lawrenz
# Processing Record 3 of Set 13 | lashio
# Processing Record 4 of Set 13 | shenjiamen
# Processing Record 5 of Set 13 | longonjo
# Processing Record 6 of Set 13 | erenhot
# Processing Record 7 of Set 13 | prior lake
# Processing Record 8 of Set 13 | sao gabriel da cachoeira
# Processing Record 9 of Set 13 | billings
# Processing Record 10 of Set 13 | kalmunai
# Processing Record 11 of Set 13 | meadow lake
# Processing Record 12 of Set 13 | littleton
# Processing Record 13 of Set 13 | soloneshnoye
# Processing Record 14 of Set 13 | pravia
# Processing Record 15 of Set 13 | portland
# Processing Record 16 of Set 13 | singleton
# Processing Record 17 of Set 13 | karasjok
# Processing Record 18 of Set 13 | yaan
# Processing Record 19 of Set 13 | palauig
# Processing Record 20 of Set 13 | pochutla
# Processing Record 21 of Set 13 | obluche
# City not found. Skipping...
# Processing Record 22 of Set 13 | macusani
# Processing Record 23 of Set 13 | kaffrine
# Processing Record 24 of Set 13 | diamantina
# Processing Record 25 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 13 | middlebury
# Processing Record 27 of Set 13 | anju
# Processing Record 28 of Set 13 | la rioja
# Processing Record 29 of Set 13 | alofi
# Processing Record 30 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 13 | palu
# Processing Record 32 of Set 13 | kuusamo
# Processing Record 33 of Set 13 | cap-aux-meules
# Processing Record 34 of Set 13 | palencia
# Processing Record 35 of Set 13 | maues
# Processing Record 36 of Set 13 | lososina
# Processing Record 37 of Set 13 | gorontalo
# Processing Record 38 of Set 13 | antalya
# Processing Record 39 of Set 13 | port hueneme
# Processing Record 40 of Set 13 | puerto colombia
# Processing Record 41 of Set 13 | sapele
# Processing Record 42 of Set 13 | bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame with the collected data on the cities
citiesData = pd.DataFrame({"City": cit, "Lat": lat, "Lng": lon, "Max Temp": maxTemp, "Humidity": humidity,
                         "Cloudiness": cloudiness, "Wind Speed": windSpeed, "Country": country, "Date": date})
# Display the data frame
citiesData.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     esperance -33.8667  121.9000     77.00        36          98
# 1   yekimovichi  54.1129   33.2965     31.35        96         100
# 2         banyo   6.7500   11.8167     69.17        73         100
# 3        areosa  41.7178   -8.8571     60.80        44           0
# 4  norman wells  65.2820 -126.8329     -2.20        71          75
#
#    Wind Speed Country        Date
# 0       14.97      AU  1615946261
# 1        5.46      RU  1615946261
# 2        4.00      CM  1615946262
# 3       13.80      PT  1615946262
# 4        3.44      CA  1615946262

# %%
# Display summary statisitcs
citiesData.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  551.000000  551.000000  551.000000  551.000000  551.000000  551.000000
# mean    21.038350   17.570793   53.184574   72.108893   50.437387    8.033303
# std     33.671116   93.058289   27.154369   20.377504   40.884307    5.719975
# min    -54.800000 -175.200000  -39.710000    4.000000    0.000000    0.290000
# 25%     -6.740700  -65.409500   34.895000   62.000000    1.000000    3.795000
# 50%     26.541200   20.750300   60.010000   76.000000   50.000000    6.890000
# 75%     48.650050  100.344850   75.990000   88.000000   90.500000   10.515000
# max     78.218600  179.316700   91.650000  100.000000  100.000000   48.340000
#
#                Date
# count  5.510000e+02
# mean   1.615946e+09
# std    8.678234e+01
# min    1.615946e+09
# 25%    1.615946e+09
# 50%    1.615946e+09
# 75%    1.615946e+09
# max    1.615946e+09

# %%
# Export the city data into a .csv
citiesData.to_csv(output_data_file, index=False)

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
over100Humid = citiesData.loc[citiesData["Humidity"]>100]
if over100Humid.empty:
    print("There are no cities that have humidity > 100%")
else:
    over100Humid
# Out:
# There are no cities that have humidity > 100%

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Make scatter plot
citiesData.plot(kind="scatter", x="Lat", y="Max Temp", title="City Latitude vs. Max Temperature (3/16/21)", 
                grid=True, edgecolors="black", s=35)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
# Save scatter plot
plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between a cities latitude and the maximum temperature. It shows that the closer a city is to the equator (latidue = 0), the hotter the maximum temperature will be.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Make scatter plot
citiesData.plot(kind="scatter", x="Lat", y="Humidity", title="City Latitude vs. Humidity (3/16/21)", 
                grid=True, edgecolors="black", s=35)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Save scatter plot
plt.savefig("output_data/lat_vs_humid.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between a cities latitude and the humidity. There does not appear to be an easily observable correlation between the two variables.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Make scatter plot
citiesData.plot(kind="scatter", x="Lat", y="Cloudiness", title="City Latitude vs. Cloudiness (3/16/21)", 
                grid=True, edgecolors="black", s=35)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Save scatter plot
plt.savefig("output_data/lat_vs_cloudy.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between a cities latitude and the cloudiness. There is no easily observable correlation between the two variables.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Make scatter plot
citiesData.plot(kind="scatter", x="Lat", y="Wind Speed", title="City Latitude vs. Wind Speed (3/16/21)", 
                grid=True, edgecolors="black", s=35)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
# Save scatter plot
plt.savefig("output_data/lat_vs_wind.png")
plt.show()

# %% [markdown]
# This scatter plot shows the relationship between a cities latitude and the wind speed. There is no easily observable correlation between the two variables.

# %% [markdown]
# ## Linear Regression

# %%
# Create data frames with the northern and southern hemisphere data
northData = citiesData.loc[citiesData["Lat"]>=0]
southData = citiesData.loc[citiesData["Lat"]<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Make scatter plot
northData.plot(kind="scatter", x="Lat", y="Max Temp", 
               title="Northern Hemisphere City Latitude vs. Max Temperature (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(northData["Lat"], northData["Max Temp"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*northData["Lat"]) + intercept
plt.plot(northData["Lat"], regressValues, "red")
plt.annotate(line_eq, (0, -40), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/north_lat_vs_temp.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: -0.902224672546157

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Make scatter plot
southData.plot(kind="scatter", x="Lat", y="Max Temp", 
               title="Southern Hemisphere City Latitude vs. Max Temperature (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(southData["Lat"], southData["Max Temp"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*southData["Lat"]) + intercept
plt.plot(southData["Lat"], regressValues, "red")
plt.annotate(line_eq, (-30, 50), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/south_lat_vs_temp.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: 0.6323136811516368

# %% [markdown]
# The linear regression in this pair of plots is modeling the relationship between a cities latitude and its maximum temperature on a given day in its respective hemisphere. The trend lines show that there is a negative correlation between these variables for the norther hemisphere and a positive correlation in the southern hemisphere. This indicates that the father north, or south a city is located from the equator, the maximum temperature will decrease.

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Make scatter plot
northData.plot(kind="scatter", x="Lat", y="Humidity", 
               title="Northern Hemisphere City Latitude vs. Humidity (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(northData["Lat"], northData["Humidity"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*northData["Lat"]) + intercept
plt.plot(northData["Lat"], regressValues, "red")
plt.annotate(line_eq, (40, 6), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/north_lat_vs_humid.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: 0.2774977071517435

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Make scatter plot
southData.plot(kind="scatter", x="Lat", y="Humidity", 
               title="Southern Hemisphere City Latitude vs. Humidity (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(southData["Lat"], southData["Humidity"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*southData["Lat"]) + intercept
plt.plot(southData["Lat"], regressValues, "red")
plt.annotate(line_eq, (-55, 20), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/south_lat_vs_humid.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: 0.2766159922141044

# %% [markdown]
# The linear regression in this pair of plots is modeling the relationship between a cities latitude and its humidity on a given day in its respective hemisphere. The trend line for the northern hemisphere has a slight positive slope, showing a trend of higher humidity percentages as the cities get farther from the equator. The trend line for the southern hemisphere is relatively flat, showing no correlation between the variables. The marginal slope of the southern hemisphere's trend line is postitive, showing that humidity percentage increases as the cities are closer to the equator. This is contradictory to the trendline found in the data from the nothern hemisphere.

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Make scatter plot
northData.plot(kind="scatter", x="Lat", y="Cloudiness", 
               title="Northern Hemisphere City Latitude vs. Cloudiness (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(northData["Lat"], northData["Cloudiness"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*northData["Lat"]) + intercept
plt.plot(northData["Lat"], regressValues, "red")
plt.annotate(line_eq, (40, 8), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/north_lat_vs_cloudy.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: 0.3542234108585294

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Make scatter plot
southData.plot(kind="scatter", x="Lat", y="Cloudiness", 
               title="Southern Hemisphere City Latitude vs. Cloudiness (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(southData["Lat"], southData["Cloudiness"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*southData["Lat"]) + intercept
plt.plot(southData["Lat"], regressValues, "red")
plt.annotate(line_eq, (-55, 50), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/south_lat_vs_cloudy.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: 0.23637362297310321

# %% [markdown]
# The linear regression in this pair of plots is modeling the relationship between a cities latitude and its cloudiness on a given day in its respective hemisphere. Both regression lines show a weak, postive trend that as the more north a city is located in its respective hemisphere, the cloudiness increases.

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Make scatter plot
northData.plot(kind="scatter", x="Lat", y="Wind Speed", 
               title="Northern Hemisphere City Latitude vs. Wind Speed (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(northData["Lat"], northData["Wind Speed"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*northData["Lat"]) + intercept
plt.plot(northData["Lat"], regressValues, "red")
plt.annotate(line_eq, (0, 35), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/north_lat_vs_wind.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: 0.0777484031545113

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Make scatter plot
southData.plot(kind="scatter", x="Lat", y="Wind Speed", 
               title="Southern Hemisphere City Latitude vs. Wind Speed (3/16/21)", s=35)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Calcuate lineaer regression equation
(slope, intercept, rvalue, pvalue, sterr) = linregress(southData["Lat"], southData["Wind Speed"])
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))

# Add line and equation to plot
regressValues = (slope*southData["Lat"]) + intercept
plt.plot(southData["Lat"], regressValues, "red")
plt.annotate(line_eq, (-40, 25), fontsize=15, color="red")

# Save scatter plot
plt.savefig("output_data/south_lat_vs_wind.png")
print("The r-value is:", rvalue)
plt.show()
# Out:
# The r-value is: -0.46893244092989456

# %% [markdown]
# The linear regression in this pair of plots is modeling the relationship between a cities latitude and its wind speed on a given day in its respective hemisphere. The northern hemisphere's regression line shows a very weak positive trend, while the regression line for the southern hemisphere shows a moderate negative trend. This implies that there is a possibility that wind speeds increase the farther a city is from the equator, particullarly in the southern hemishphere. This would need further analysis and serveral days of observable trends to confirm.

# %%
# Out:
# The r-value is: 0.017128274759839232
